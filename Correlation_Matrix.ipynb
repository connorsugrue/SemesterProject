# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
from scipy.integrate import solve_ivp
from scipy.optimize import curve_fit
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
all_time_stats = pd.read_csv("nba_team_stats_00_to_21.csv")

# %%
corr_matrix = all_time_stats.corr()
target_corr = corr_matrix["W"].abs()

# %%
sns.heatmap(corr_matrix, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
features = target_corr[target_corr > 0.4].index.tolist()

# %%
features.remove('W')
features.remove('L')
features.remove("WIN%")

# %%
features
# Out:
# ['FG%', '3P%', 'BLKA', '+/-']
